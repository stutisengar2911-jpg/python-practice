# %%
# wap to print prime number btw start and end ?(take user input)
start=int(input("enter any number"))
end=int(input("enter any number"))
for i in range(start,end+1):
    if i>1:
        for j in range(2,i):
            if i%j==0:
                break
        else:
            print(i,end=" ")
# Out:
# enter any number 20
# enter any number 50
# 23 29 31 37 41 43 47

# %%
#Q10. Write recursion function for print fibonaaci series upto n term?
def fibo(n):
    if n==1:
        return 0
    elif n==2:
        return 1
    else:
        return fibo(n-1)+fibo(n-2)
fibo(10)
# Out:
# 34
