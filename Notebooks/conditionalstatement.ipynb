# %%
# wap to check wheather a user is eligible to vote or not 
age=int(input("enter the your age:"))
if age>=18:
    print("eligible")
else:
    print("not eligible")
# Out:
# enter the your age: 23
# eligible

# %%
#wap to check wheather a given number is even or odd?
num=int(input("enter the number"))
if sum%2==0:
    print("even")
else:
    print("odd")
# Out:
# enter the number 45
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 #wap to check wheather a given number is even or odd?
#       2 num=int(input("enter the number"))
# ----> 3 if sum%2==0:
#       4     print("even")
#       5 else:
#
# TypeError: unsupported operand type(s) for %: 'builtin_function_or_method' and 'int'

# %%
#wap to check wheather a given number is even or odd?
num=int(input("enter the number"))
if num%2==0:
    print("even number")
else:
    print("odd number")
# Out:
# enter the number 45
# odd number
