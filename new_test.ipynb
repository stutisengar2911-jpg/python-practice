# %%
print("Hey")
# Out:
# Hey

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	.ipynb_checkpoints/
# 	new_test.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .

# %%
# !git commit -m "inittial Commit"
# Out:
# [main 8287d25] inittial Commit
#  2 files changed, 85 insertions(+)
#  create mode 100644 .ipynb_checkpoints/new_test-checkpoint.ipynb
#  create mode 100644 new_test.ipynb

# %%
# !git push
# Out:
# To https://github.com/stutisengar2911-jpg/python-practice.git
#    396b751..8287d25  main -> main
